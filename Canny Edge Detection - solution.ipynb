# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# Read in the image
image = cv2.imread('images/mt_rainier.jpeg')

# Make a copy of the image
image_copy = np.copy(image)

# Change color to RGB (from BGR)
image_copy = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

plt.imshow(image_copy)

# %%
# Convert the image to grayscale for processing
gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)

plt.imshow(gray, cmap='gray')

# %% [markdown]
# ### Implement Canny edge detection

# %%
# Define lower and upper thresholds for hysteresis

lower = 120
upper = 240


blur = cv2.GaussianBlur(image_copy,(5, 5), 0)

edges = cv2.Canny(blur, lower, upper)

plt.imshow(edges, cmap='gray')

# %%
# Try Canny using "wide" and "tight" thresholds

wide = cv2.Canny(blur, 30, 100)
tight = cv2.Canny(blur, 180, 240)
 
    
# Display the images
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))

ax1.set_title('wide')
ax1.imshow(wide, cmap='gray')

ax2.set_title('tight')
ax2.imshow(tight, cmap='gray')

# %%
# contours based on found threshold
im2, contours, hierarchy = cv2.findContours(tight, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

print (len(contours))

image_copy2 = np.copy(image_copy)
all_contours = cv2.drawContours(image_copy2, contours[300:700], -1, (0,255,0), 2)

all_contours = cv2.drawContours(all_contours, contours[0:300], -1, (255,0,0), 2)

all_contours = cv2.drawContours(all_contours, contours[700:1311], -1, (0,0,255), 2)


# Display the images
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))

ax1.set_title('contours')
ax1.imshow(all_contours)


ax2.set_title('approx')
ax2.imshow(approximation)
# Out:
# 148
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f6b76d9c0d72> in <module>()
#      22
#      23 ax2.set_title('approx')
# ---> 24 ax2.imshow(approximation)
#
# NameError: name 'approximation' is not defined
